# %% [markdown]
# <img src = "../../images/3_logos.png" width = 600, align = "center">
# <br>
# <h1 align=center><font size = 5>Consommation d'alcool chez les étudiants</font></h1>
# <h2 align=center><font size = 5>Apply</font></h2>

# %% [markdown]
# ### 1. Import des librairies

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Import du jeu de données [adresse](https://needemand.com/keepsmiling2/index.php/s/CGKg6K6Ysk6FEs9).

# %% [markdown]
# ### 3. Stocker les données dans une variable *alcool*.

# %%
alcool = pd.read_csv("C:/Users/Dell/Desktop/td_python/pandas/4_apply/Data/student-mat.csv", sep=',')
alcool.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ### 4. Selctionner les colonnes allant de 'school' à 'guardian'.

# %%
alcool.loc[:,'school':'guardian'].head(1)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher
#
#    reason guardian
# 0  course   mother

# %% [markdown]
# ### 5. Créer une fonction lambda qui met les chaines de caractères en majuscule.

# %%
alcool.apply(lambda x: x.astype(str).str.upper(), axis=1).head()
# Out:
#   school sex age address famsize Pstatus Medu Fedu     Mjob      Fjob  \
# 0     GP   F  18       U     GT3       A    4    4  AT_HOME   TEACHER
# 1     GP   F  17       U     GT3       T    1    1  AT_HOME     OTHER
# 2     GP   F  15       U     LE3       T    1    1  AT_HOME     OTHER
# 3     GP   F  15       U     GT3       T    4    2   HEALTH  SERVICES
# 4     GP   F  16       U     GT3       T    3    3    OTHER     OTHER
#
#                   ...                 freetime goout Dalc Walc health  \
# 0                 ...                        3     4    1    1      3
# 1                 ...                        3     3    1    1      3
# 2                 ...                        3     2    2    3      3
# 3                 ...                        2     2    1    1      5
# 4                 ...                        3     2    1    2      5
#
#   absences  G1  G2  G3                               Upper
# 0        6   5   6   6  <MAP OBJECT AT 0X000001B4AC02EBA8>
# ...

# %% [markdown]
# ### 6. Mettre les colonnes Mjob et Fjob en majuscule.

# %%
alcool[['Mjob','Fjob']].apply(lambda x: x.str.upper(), axis=1).head()
# Out:
#       Mjob      Fjob
# 0  AT_HOME   TEACHER
# 1  AT_HOME     OTHER
# 2  AT_HOME     OTHER
# 3   HEALTH  SERVICES
# 4    OTHER     OTHER

# %% [markdown]
# ### 7. Afficher les 5 derniers enregistrements du jeu de données.

# %%
alcool.tail(5)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#                     ...                 freetime goout  Dalc  Walc  health  \
# 390                 ...                        5     4     4     5       4
# 391                 ...                        4     5     3     4       2
# 392                 ...                        5     3     3     3       3
# 393                 ...                        4     1     3     4       5
# 394                 ...                        2     3     3     3       5
#
# ...

# %% [markdown]
# ### 8. Remarquer que le dataframe d'origine est encore en miniscule. Apporter une solution.

# %%
alcool=alcool.apply(lambda x: x.astype(str).str.upper(), axis=1)
alcool.head()
# Out:
#   school sex age address famsize Pstatus Medu Fedu     Mjob      Fjob  \
# 0     GP   F  18       U     GT3       A    4    4  AT_HOME   TEACHER
# 1     GP   F  17       U     GT3       T    1    1  AT_HOME     OTHER
# 2     GP   F  15       U     LE3       T    1    1  AT_HOME     OTHER
# 3     GP   F  15       U     GT3       T    4    2   HEALTH  SERVICES
# 4     GP   F  16       U     GT3       T    3    3    OTHER     OTHER
#
#                   ...                 freetime goout Dalc Walc health  \
# 0                 ...                        3     4    1    1      3
# 1                 ...                        3     3    1    1      3
# 2                 ...                        3     2    2    3      3
# 3                 ...                        2     2    1    1      5
# 4                 ...                        3     2    1    2      5
#
#   absences  G1  G2  G3                               Upper
# 0        6   5   6   6  <MAP OBJECT AT 0X000001B4AC02EBA8>
# ...

# %% [markdown]
# ### 9. Créer une fonction nommée *majority* qui retourne un booléen dans une nouvelle colonne *conso_legale* (majorité à 18 ans)

# %%
alcool['majority'] = alcool['age'].values.astype(int)>=18
alcool
# Out:
#   school sex age address famsize Pstatus Medu Fedu     Mjob      Fjob  \
# 0     GP   F  18       U     GT3       A    4    4  AT_HOME   TEACHER
# 1     GP   F  17       U     GT3       T    1    1  AT_HOME     OTHER
# 2     GP   F  15       U     LE3       T    1    1  AT_HOME     OTHER
# 3     GP   F  15       U     GT3       T    4    2   HEALTH  SERVICES
# 4     GP   F  16       U     GT3       T    3    3    OTHER     OTHER
#
#     ...    goout Dalc Walc health absences  G1  G2  G3  \
# 0   ...        4    1    1      3        6   5   6   6
# 1   ...        3    1    1      3        4   5   5   6
# 2   ...        2    2    3      3       10   7   8  10
# 3   ...        2    1    1      5        2  15  14  15
# 4   ...        2    1    2      5        4   6  10  10
#
#                                 Upper majority
# 0  <MAP OBJECT AT 0X000001B4AC02EBA8>     True
# 1  <MAP OBJECT AT 0X000001B4AC02EBA8>    False
# 2  <MAP OBJECT AT 0X000001B4AC02EBA8>    False
# ...

# %% [markdown]
# <hr>
# Copyright &copy; 2018 Hatem & Driss @NEEDEMAND
