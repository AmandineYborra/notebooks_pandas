# %% [markdown]
# <img src = "images/3_logos.png" width = 600, align = "center">
# <br>
# <h1 align=center><font size = 5>Chipoltle</font></h1>
# <h2 align=center><font size = 5>Filtrer et Trier</font></h2>

# %% [markdown]
# ### 1. Importer les librairies nécessaires

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Importer le jeu de données depuis [adresse](https://needemand.com/keepsmiling2/index.php/s/9KGweKQ3SDgJNYQ).

# %% [markdown]
# ### 3. Affecter les données à une variable chipo.

# %%
chipo = pd.read_table("C:/Users/Dell/Desktop/td_python/pandas/Importer_&_Explorer/data/chipotle.tsv", low_memory = False)
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ###  4. Combien de produits coûtent plus de $10.00?

# %%
chipo['new_item_price'] = chipo['item_price'].map(lambda x: x.lstrip('$')).astype(float)
chipo.dtypes['new_item_price']
len(chipo[chipo['new_item_price']>10])
# Out:
# 1130

# %% [markdown]
# ###  5. Quel est le prix de chaque produit ?
# ###### Afficher un dataframe de 2 colonnes item_name et item_price

# %%
produitPrix = chipo.loc[:, ['item_name', 'new_item_price']]
produitPrix.head()
# Out:
#                                item_name  new_item_price
# 0           Chips and Fresh Tomato Salsa            2.39
# 1                                   Izze            3.39
# 2                       Nantucket Nectar            3.39
# 3  Chips and Tomatillo-Green Chili Salsa            2.39
# 4                           Chicken Bowl           16.98

# %% [markdown]
# ### 6. Trier nom d'article

# %%
produitPrix.sort_values(ascending=True,by='item_name')
# Out:
#               item_name  new_item_price
# 3389  6 Pack Soft Drink           12.98
# 341   6 Pack Soft Drink            6.49
# 1849  6 Pack Soft Drink            6.49
# 1860  6 Pack Soft Drink            6.49
# 2713  6 Pack Soft Drink            6.49
# 3422  6 Pack Soft Drink            6.49
# 553   6 Pack Soft Drink            6.49
# 1916  6 Pack Soft Drink            6.49
# 1922  6 Pack Soft Drink            6.49
# 1937  6 Pack Soft Drink            6.49
# 3836  6 Pack Soft Drink            6.49
# 298   6 Pack Soft Drink            6.49
# 1976  6 Pack Soft Drink            6.49
# 1167  6 Pack Soft Drink            6.49
# 3875  6 Pack Soft Drink            6.49
# 1124  6 Pack Soft Drink            6.49
# 3886  6 Pack Soft Drink            6.49
# 2108  6 Pack Soft Drink            6.49
# 3010  6 Pack Soft Drink            6.49
# 4535  6 Pack Soft Drink            6.49
# 4169  6 Pack Soft Drink            6.49
# 4174  6 Pack Soft Drink            6.49
# ...

# %% [markdown]
# ### 7. Quelle était la quantité commandée de l'article le plus cher ?

# %%
chipo.loc[:, ['quantity', 'item_name', 'new_item_price']].sort_values(ascending=False,by='new_item_price').head(1)
# Out:
#       quantity                     item_name  new_item_price
# 3598        15  Chips and Fresh Tomato Salsa           44.25

# %% [markdown]
# ### 8. Combien de fois l'article Veggie Salad Bowl a t-il été commandé?

# %%
chipo_veggie_salad_bowl=chipo[(chipo['item_name']=='Veggie Salad Bowl')]
len(chipo_veggie_salad_bowl)
# Out:
# 18

# %% [markdown]
# ### 9. Combien de commandes comportent plus d'une Canned Soda?

# %%
chipo_canned_soda = chipo[(chipo.item_name == "Canned Soda") & (chipo.quantity > 1)]
len(chipo_drink_steak_bowl)
# Out:
# 20

# %% [markdown]
# <hr>
# Copyright &copy; 2018 Hatem & Driss @NEEDEMAND
